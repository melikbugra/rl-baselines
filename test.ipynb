# %%
import continuous_maze_env
from rl_baselines.common.env_wrappers import make_atari_env, make_box2d_viz_env
import gymnasium as gym
import matplotlib.pyplot as plt
from rl_baselines.common.env_wrappers.box2d_wrappers import MaxAndSkipEnv, ProcessFrame84, ImageToPyTorch, BufferWrapper, ScaledFloatFrame

# %%
env = gym.make("ContinuousMazeViz-v0", level="level_three", obs_shape=(96, 96, 3))
# Out:
# MESA: error: ZINK: failed to choose pdev
# glx: failed to create drisw screen

# %%
obs, _ = env.reset()
plt.imshow(obs)

# %%
env = MaxAndSkipEnv(env)

# %%
obs, _ = env.reset()
plt.imshow(obs)

# %%
env = ProcessFrame84(env, crop=False)

# %%
obs, _ = env.reset()
plt.imshow(obs)
